# %%
from google.colab import drive
drive.mount('/content/drive')

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasetD1.csv')
#data2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Loan_defaultD3.csv')
#print(data1)
#print("****************************")

# Seleccionar las dos primeras columnas numéricas
X1 = data1.iloc[:, [3, 4]].fillna(data1.iloc[:, [3, 4]].mean()).values
print(X1)
print("****************************")


# Normalizar los datos
scaler = StandardScaler()
X1_normalized = scaler.fit_transform(X1)
print(X1_normalized)
# Out:
# [[68.         22.73      ]
#  [77.         27.42      ]
#  [25.         31.95      ]
#  ...
#  [48.         27.23691351]
#  [62.30951592 23.29748133]
#  [82.         22.03125   ]]
# ****************************
# [[ 3.47323959e-01 -7.95156654e-01]
#  [ 8.96647283e-01 -2.17494009e-01]
#  [-2.27722081e+00  3.40461594e-01]
#  ...
#  [-8.73394538e-01 -2.40044591e-01]
#  [-8.67372661e-16 -7.25260542e-01]
#  [ 1.20182691e+00 -8.81220998e-01]]

# %%
# Visualizar datos originales (antes de K-Means)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(X1[:, 0], X1[:, 1], s=50, alpha=0.5)
plt.xlabel("$x_1$", fontsize=14)
plt.ylabel("$x_2$", fontsize=14, rotation=0)
plt.title("Datos originales datasetD1")
plt.tight_layout()
plt.show()

# %%
# Establecer hiperparámetros y aplicar K-Means con 20 clusters
kmeans1 = KMeans(n_clusters=20, random_state=42)
y1 = kmeans1.fit_predict(X1_normalized)

# Visualizar clusters
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(X1_normalized[:, 0], X1_normalized[:, 1], c=y1, s=50, cmap='viridis')
plt.xlabel("$x_1$", fontsize=14)
plt.ylabel("$x_2$", fontsize=14, rotation=0)
plt.title("Clusters datasetD1 (20 clusters)")
plt.colorbar(label='Cluster')
plt.tight_layout()
plt.show()

# %%
# Calcular Silhouette Score para determinar número óptimo de clusters
range_n_clusters = range(2, 21)
silhouette_scores1 = []

for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    y1_temp = kmeans.fit_predict(X1_normalized)
    silhouette_scores1.append(silhouette_score(X1_normalized, y1_temp))

# Graficar Silhouette Scores
plt.figure(figsize=(10, 5))
plt.plot(range_n_clusters, silhouette_scores1, marker='o', label='datasetD1')
plt.xlabel("Número de clusters")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score vs Número de Clusters")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-2f80be21dfd4> in <cell line: 0>()
#       6     kmeans = KMeans(n_clusters=n_clusters, random_state=42)
#       7     y1_temp = kmeans.fit_predict(X1_normalized)
# ----> 8     silhouette_scores1.append(silhouette_score(X1_normalized, y1_temp))
#       9
#      10 # Graficar Silhouette Scores
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# ...

# %%
# Mostrar el número óptimo de clusters (máximo Silhouette Score)
optimal_clusters1 = range_n_clusters[np.argmax(silhouette_scores1)]
print(f"Número óptimo de clusters para datasetD1: {optimal_clusters1}")

# Mostrar Silhouette Score para 20 clusters
print(f"Silhouette Score para datasetD1 con 20 clusters: {silhouette_score(X1_normalized, y1):.3f}")
# Out:
# Número óptimo de clusters para datasetD1: 3
